# %% [markdown]
# <a href="https://colab.research.google.com/github/deepakyadav043/Python-Pandas_Library/blob/main/Pandas__(1)110726.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas Backup Class — E-Commerce Sales & Customer Analytics
#
# Welcome! This notebook is built for **practice, not memorization**.
#
# **Dataset:** `ecommerce_sales_data.csv` — a realistic (but intentionally messy)
# e-commerce dataset with customers, orders, and business metrics.
#
# > 💡 Tip: This dataset was created ON PURPOSE with missing values, duplicates,
# > wrong data types, inconsistent text, and outliers — because real company
# > data always looks like this. Cleaning it is part of the lesson!

# %% [markdown]
# ## 1. Reading the Dataset — `read_csv`

# %%
import pandas as pd
df = pd.read_csv('ecommerce_sales_data 11072026.csv')
df
#df = pd.read_excel('ecommerce_sales_data.excel ')
# Out:
#       Row_ID Customer_ID  Customer_Name    Gender   Age       City  \
# 0          1   CUST00265   Sneha Sharma      Male  35.0    Chennai
# 1          2   CUST01312    Rahul Joshi    Female  23.0     Jaipur
# 2          3   CUST00608    Priya Mehta      Male  18.0     Bhopal
# 3          4   CUST00374   Aditya Gupta         F  37.0     Bhopal
# 4          5   CUST00688  Reyansh Singh    Female  27.0  Hyderabad
# ...      ...         ...            ...       ...   ...        ...
# 4300    4301   CUST00673     Diya Singh   Female   29.0     bhopal
# 4301    4302   CUST01038   Rahul Sharma      Male  49.0     Jaipur
# 4302    4303   CUST01417    Rahul Joshi    Female  37.0    Chennai
# 4303    4304   CUST00320    Karan Patel      Male  18.0     Bhopal
# 4304    4305   CUST00780    Karan Verma    Female  40.0        NaN
#
#                State Country Membership_Type   Order_ID  ... Time_On_Website  \
# 0         Tamil Nadu   India            Gold  ORD103884  ...             5.8
# 1          Rajasthan   India            Gold  ORD103992  ...             6.7
# 2     Madhya Pradesh   India         Regular  ORD103326  ...            15.6
# 3     Madhya Pradesh   India          Silver  ORD100652  ...            17.7
# 4          Telangana   India            Gold  ORD101040  ...             5.1
# ...              ...     ...             ...        ...  ...             ...
# 4300  Madhya Pradesh   India          Silver  ORD100919  ...             9.5
# 4301       Rajasthan   India        Platinum  ORD102550  ...            24.0
# 4302      Tamil Nadu   India          Silver  ORD100537  ...            23.6
# 4303  Madhya Pradesh   India        Platinum  ORD101220  ...            11.4
# 4304  Madhya Pradesh   India            Gold  ORD100544  ...             4.7
#
#      Rating Returned_Product Customer_Satisfaction Salesperson Region  \
# 0       4.0               No        Very Satisfied    Agent_15  South
# 1       2.0               No        Very Satisfied    Agent_17  South
# 2       5.0               No             Satisfied    Agent_04  South
# 3       3.0               No                   NaN    Agent_19   East
# 4       4.0              Yes             Satisfied    Agent_12   East
# ...     ...              ...                   ...         ...    ...
# 4300    4.0               No                   NaN    Agent_18  North
# 4301    4.0              Yes           Unsatisfied    Agent_13   East
# 4302    3.0               No                   NaN    Agent_08  North
# 4303    5.0               No               Neutral    Agent_03   East
# 4304    2.0               No                   NaN    Agent_03   East
#
#        Warehouse   Profit     Cost   Revenue
# 0        WH-East   543.26  7950.40  10473.10
# 1     WH-Central   316.68  2412.48   3388.61
# 2        WH-East  1536.93  3649.22   6373.82
# 3        WH-East   362.02  1609.59   2432.95
# 4        WH-West   553.81  4702.15   6598.52
# ...          ...      ...      ...       ...
# 4300    WH-South   583.64  3831.97   5566.17
# 4301  WH-Central   942.26  3269.80   5203.57
# 4302    WH-North   310.56  2318.76   3241.43
# 4303    WH-South   773.99  2396.13   4093.36
# 4304     WH-West   487.83  1686.80   2779.98
#
# [4305 rows x 33 columns]

# %% [markdown]
# ## 2. First Look at the Data — `head`, `tail`, `sample`

# %%
df.head()
df.tail()
df.sample(5)
# Out:
#       Row_ID Customer_ID Customer_Name  Gender   Age       City  \
# 187      188   CUST01309   Simran Iyer    Male   NaN    Kolkata
# 778      779   CUST00885     Sai Reddy       F  34.0     indore
# 3846    3847   CUST00505  Ishaan Gupta  Female  58.0     indore
# 2295    2296   CUST00277   Arjun Patel    Male  21.0  Ahmedabad
# 3676    3677   CUST00096   Rahul Singh  Female  32.0        NaN
#
#                State Country Membership_Type   Order_ID  ... Time_On_Website  \
# 187      West Bengal   India         Regular  ORD103509  ...             1.3
# 778   Madhya Pradesh   India        Platinum  ORD104174  ...             2.8
# 3846  Madhya Pradesh   India          Silver  ORD102137  ...             5.2
# 2295         Gujarat   India        Platinum  ORD101205  ...             8.5
# 3676         Gujarat   India          Silver  ORD102867  ...             8.3
#
#      Rating Returned_Product Customer_Satisfaction Salesperson Region  \
# 187     2.0               No        Very Satisfied    Agent_13   West
# 778     5.0               No               Neutral    Agent_04   East
# 3846    3.0               No           Unsatisfied    Agent_03  North
# 2295    4.0               No        Very Satisfied    Agent_03   East
# 3676    5.0               No      Very Unsatisfied    Agent_06  North
#
#        Warehouse   Profit     Cost   Revenue
# 187     WH-North  1162.72  3812.06   6124.30
# 778      WH-East   1693.9  3673.54   6670.27
# 3846    WH-South   441.45  2616.57   3821.44
# 2295     WH-East  3194.56  9804.06  15954.38
# 3676  WH-Central   551.45  1868.58   2975.65
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 3. Understanding the Structure — `shape`, `columns`, `dtypes`, `info`, `describe`

# %%
#df.shape
#df.columns
#df.dtypes
#df.info()
df.describe()
# Out:
#             Row_ID          Age     Quantity     Discount  Shipping_Cost  \
# count  4305.000000  3875.000000  4305.000000  4090.000000    4305.000000
# mean   2153.000000    34.823484     4.164692    12.268120      90.585370
# std    1242.890784    11.167811     5.002189    10.190367     243.355182
# min       1.000000    -5.000000    -4.000000     0.076096    -186.410000
# 25%    1077.000000    28.000000     3.000000     6.511042      37.760000
# 50%    2153.000000    34.000000     4.000000    10.657993      66.350000
# 75%    3229.000000    41.000000     5.000000    16.177651     106.290000
# max    4305.000000   150.000000   120.000000   200.000000    5000.000000
#
#                Tax  Total_Amount  Website_Visits  Time_On_Website  \
# count  4305.000000   4305.000000     4305.000000      4305.000000
# mean   1004.734353   6666.305317        6.221138        11.275796
# std     719.154651   4714.518859       29.459290        35.818504
# min      32.680000    317.770000        1.000000         1.000000
# 25%     488.840000   3279.720000        2.000000         3.200000
# 50%     828.590000   5490.060000        3.000000         6.700000
# 75%    1312.110000   8707.290000        6.000000        12.400000
# max    6351.530000  41714.370000      500.000000       600.000000
#
#             Rating          Cost        Revenue
# count  3875.000000   4305.000000    4305.000000
# mean      3.188903   3457.644314    8526.734167
# std       1.096496   2552.482952   49922.640734
# min      -2.000000    110.210000     181.530000
# 25%       2.000000   1658.730000    2725.590000
# 50%       3.000000   2825.550000    4623.320000
# 75%       4.000000   4519.430000    7329.650000
# max      10.000000  22330.830000  850000.000000

# %% [markdown]
# ## 4. Selecting Data — Indexing, `loc`, `iloc`

# %%
df['Row_ID'] #single level selecting
df.columns
df['Order_Status'] ##Multi.... level selecting
df[['Website_Visits','Rating']]

#loc

df.loc[0:5,['Order_Status','Row_ID']]# df.loc[row,column]

# df.loc[]
#iloc
df.iloc[5:11,0:5] #[row,column]
# Out:
#     Row_ID Customer_ID Customer_Name  Gender   Age
# 5        6   CUST00782   Rahul Patel  Female  36.0
# 6        7   CUST00317      Sai Nair  Female  27.0
# 7        8   CUST00628   Aarav Singh       M  37.0
# 8        9   CUST01263  Aditya Verma    Male  32.0
# 9       10   CUST00477   Sneha Singh    Male   NaN
# 10      11   CUST00975   Rahul Mehta    Male  27.0

# %% [markdown]
# ## 5. Filtering Data (Boolean Conditions)

# %%
df[df['Order_Status'] == 'Delivered']
df[(df['Order_Status'] == "Delivered") & (df['Total_Amount'] >10000)]
#query()
df.query('Order_Status == "Delivered" & Total_Amount > 10000').head()
# Out:
#     Row_ID Customer_ID  Customer_Name  Gender   Age     City           State  \
# 16      17   CUST01161       Sai Iyer    Male  37.0  Chennai      Tamil Nadu
# 34      35   CUST00772    Kabir Gupta    MALE  30.0  kolkata     West Bengal
# 38      39   CUST00678    Pooja Verma  Female  27.0    Delhi           Delhi
# 69      70   CUST00800  Reyansh Patel  Female  47.0   Bhopal  Madhya Pradesh
# 84      85   CUST01051    Sneha Patel  Female  32.0   Mumbai     Maharashtra
#
#    Country Membership_Type   Order_ID  ... Time_On_Website Rating  \
# 16   India          Silver  ORD103892  ...             6.1    3.0
# 34   India         Regular  ORD102216  ...             6.0    NaN
# 38   India         Regular  ORD102498  ...             9.6    NaN
# 69   India         Regular  ORD100378  ...            23.6    4.0
# 84   India            Gold  ORD102208  ...             1.5    2.0
#
#    Returned_Product Customer_Satisfaction Salesperson Region   Warehouse  \
# 16               No        Very Satisfied    Agent_06  South    WH-North
# 34               No           Unsatisfied    Agent_04  North    WH-North
# 38               No             Satisfied    Agent_07  South     WH-West
# 69               No               Neutral    Agent_09  South     WH-West
# 84               No               Neutral    Agent_05  North  WH-Central
#
#      Profit      Cost   Revenue
# 16      NaN   6878.68  12565.44
# 34      NaN  13469.97  19845.79
# 38  3361.97   4556.85   9724.27
# 69  1053.77   7263.23  10195.28
# 84   980.34  10099.09  13621.19
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 6. Sorting Data — `sort_values`

# %%
df.sort_values('Total_Amount',ascending = False)
df.sort_values('Total_Amount',ascending = True)
# Out:
#       Row_ID Customer_ID  Customer_Name  Gender   Age       City  \
# 1324    1325   CUST00480     Pooja Iyer    Male  41.0     Mumbai
# 1623    1624   CUST00295  Reyansh Reddy  Female  44.0      Delhi
# 2599    2600   CUST00034   Simran Mehta  Female  22.0  Ahmedabad
# 2448    2449   CUST00308    Rohan Singh    Male  30.0    Chennai
# 3612    3613   CUST01170   Simran Joshi  Female  27.0  Bengaluru
# ...      ...         ...            ...     ...   ...        ...
# 1531    1532   CUST00880   Ishaan Singh    Male   NaN    Chennai
# 690      691   CUST00723    Rahul Patel  Female  31.0    Chennai
# 2575    2576   CUST00354    Aarav Patel    Male  31.0    Lucknow
# 2989    2990   CUST01217      Diya Nair  FEMALE  36.0    Jaipur
# 2017    2018   CUST01090   Sneha Sharma  Female  25.0      Delhi
#
#               State Country Membership_Type   Order_ID  ... Time_On_Website  \
# 1324    Maharashtra   India          Silver  ORD101324  ...            12.7
# 1623          Delhi   India         Regular  ORD103806  ...            11.4
# 2599        Gujarat   India         Regular  ORD100307  ...             8.0
# 2448     Tamil Nadu   India          Silver  ORD101764  ...             3.8
# 3612      Karnataka   India          Silver  ORD101472  ...            13.9
# ...             ...     ...             ...        ...  ...             ...
# 1531     Tamil Nadu   India          Silver  ORD102584  ...            13.5
# 690      Tamil Nadu   India         Regular  ORD102537  ...            16.1
# 2575  Uttar Pradesh   India         Regular  ORD103757  ...             8.2
# 2989      Rajasthan   India          Silver  ORD100332  ...            10.2
# 2017          Delhi   India            Gold  ORD102999  ...             2.8
#
#      Rating Returned_Product Customer_Satisfaction Salesperson Region  \
# 1324    3.0               No        Very Satisfied    Agent_17  South
# 1623    3.0               No             Satisfied    Agent_07  South
# 2599    3.0               No        Very Satisfied    Agent_05  North
# 2448    3.0              Yes             Satisfied    Agent_13  North
# 3612    3.0               No                   NaN    Agent_03  North
# ...     ...              ...                   ...         ...    ...
# 1531    3.0               No                   NaN    Agent_07  North
# 690     3.0               No               Neutral    Agent_20  North
# 2575    3.0               No        Very Satisfied    Agent_18   East
# 2989    3.0               No        Very Satisfied    Agent_01  South
# 2017    3.0               No             Satisfied    Agent_12   West
#
#        Warehouse   Profit      Cost   Revenue
# 1324  WH-Central    13.55    173.38    252.35
# 1623     WH-West   -60.63    142.08    231.52
# 2599    WH-North  -129.29    110.21    181.53
# 2448     WH-West    51.01    172.03    307.18
# 3612    WH-South      NaN    167.99    283.61
# ...          ...      ...       ...       ...
# 1531     WH-West  8137.44  14581.79  27772.59
# 690     WH-South  7714.86  15582.37  28485.52
# 2575    WH-South  2466.92  22067.63  29960.23
# 2989    WH-South  5583.57  22330.83  34192.60
# 2017     WH-East  8453.37  20404.80  35286.27
#
# [4305 rows x 33 columns]

# %% [markdown]
# ## 7. Exploring Categories — `value_counts`, `unique`, `nunique`

# %%
#df['Order_Status'].value_counts()
#df['City'].unique()
df['City'].nunique()
# Out:
# 49

# %% [markdown]
# ## 8. Handling Missing Values — `isnull`, `fillna`, `dropna`

# %%
#df.isnull().sum()
df['City'].fillna(df['City'].mode()[0],inplace = True)
df['City'].isnull().sum()
# Out:
# /tmp/ipykernel_1499/4240452254.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['City'].fillna(df['City'].mode()[0],inplace = True)
# np.int64(0)

# %% [markdown]
# ## 9. Duplicate Handling

# %% [markdown]
# ## 10. `groupby`, `agg`, and `transform`

# %% [markdown]
# ## 11. Data Type Fixing (`astype`)
